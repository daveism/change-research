# %%
import pandas as pd
from pandas import json_normalize
import json
import numpy as np
df = pd.read_csv("data/data.csv")
# screen_size = df['screen_size']
# print(df.head(5))
# print(screen_size)
# print(stjson)
screenSizeDF = df['screen_size'].apply(json.loads)
screenSizeDFList = list(screenSizeDF)
screenSizeDFJSONString = json.dumps(screenSizeDFList)
# df = pd.read_json(screenSizeDFJSONString)
df = df.join(pd.read_json(screenSizeDFJSONString))
# print(df)


gridAnswersDF = df['grid_answers'].apply(json.loads)
DFList = json.dumps(list(gridAnswersDF))
gridAnswersDF['card_id'] = np.arange(len(gridAnswersDF))
print(gridAnswersDF)
# d
# # susAnswersDF = df['grid_answers'].apply(json.loads)
# # susAnswersDFList = list(susAnswersDF)
# # susAnswersDFJSONString = json.dumps(susAnswersDFList)
# # # this actually works
# # data = susAnswersDFList
# # # sdf = pd.Series(data, name='grid_answers').to_frame()
# # # sdf['index'] = np.arange(len(sdf))
# # # print(sdf)
# # df.grid_answers.apply(pd.Series)


# df2 = s.transpose()
# df1 = pd.DataFrame(data)
# df2 = pd.DataFrame(data.key())

# df1['index'] = np.arange(len(df1))
# df2 = pd.pivot_table(df1,index=['index'],columns=['key'],values=['value'],aggfunc=np.sum).reset_index()
# print(df2)

#  pd.crosstab(df1['value'], df1['key']).reset_index()
    
        # susAnswersDF = df['grid_answers'].apply(json.loads)
        # print(susAnswersDF)
        # susAnswersDFList = list(susAnswersDF)
        # susAnswersDFJSONString = json.dumps(susAnswersDFList)
        # # this actually works
        # data = susAnswersDFList[0]
        # df1 = pd.DataFrame(data)
        # # print(df1)
        # df2 = pd.crosstab(df1['value'], df1['key']).reset_index()
        # print(df2)
        # #  pt.rename_axis(None, axis=1).reset_index()
        # # df3 = df1.set_index(['value', 'key'], append=True).rename_axis([None, None]).squeeze().unstack()
        # # print(df3)

# df.join(pd.read_json(susAnswersDFJSONString))

# pd.DataFrame.from_dict(data)
# pd.DataFrame.from_records(data)

# js = pd.read_json(susAnswersDFJSONString)
# df2 = pd.DataFrame(js)
# print(susAnswersDFList[0])

# ga = df['grid_answers']
# print(ga.keys())

# json_normalize(df['grid_answers'])
# gridAnswersDF = df['grid_answers'].apply(json.loads)
# print(gridAnswersDF)
# result = json_normalize(df['grid_answers'])
# print(result)
# gridAnswersDF = df['grid_answers'].apply(json.loads)
# gridAnswersDFList = list(gridAnswersDF)[0].to_dict()
# print(gridAnswersDF)

# for key, value in dictionary.items():
#      df = value
#      df.loc[:,'Country'] = key
#      final_df = pd.concat([df, final_df], 0)
        
# final_df

# idx = df.grid_answers.apply(pd.Series).stack().index
# df1 = pd.DataFrame(df.grid_answers.apply(pd.Series).stack().values.tolist(),index=idx).reset_index()
# print(df1)
# print()
# # print(df['grid_answers'].apply(json.loads))
# Idx=df.set_index(['COL1','COL2']).grid_answers.apply(pd.Series).stack().index

# pd.DataFrame(df.set_index(['COL1','COL2']).grid_answers.apply(pd.Series).stack().values.tolist(),index=Idx).reset_index().drop('level_2',1)

 
# df = df.join(pd.read_json(screenSizeDFJSONString))
# gridAnswersDF = df['grid_answers'].apply(json.loads)
# gridAnswersDFList = list(gridAnswersDF)
# gridAnswersDFJSONString = json.dumps(gridAnswersDFList)
# # df2 = pd.read_json(gridAnswersDFJSONString)
# print(df['grid_answers'][0])

    
# pd.DataFrame.from_records(gridAnswersDF.value.dropna().tolist())

# pd.DataFrame.from_records(df1.value.dropna().tolist())
# df1.dic.apply(pn.Series)

# df = df.join(pd.read_json(gridAnswersDFJSONString))

# susAnswersDF = df['sus_answers'].apply(json.loads)
# susAnswersDFList = list(susAnswersDF)
# susAnswersDFJSONString = json.dumps(susAnswersDFList)
# df.join(pd.read_json(susAnswersDFJSONString))

# print(df.head(5))
# Out:
# 0        [{'key': 'grid-box-42', 'value': 42}, {'key': ...
# 1        [{'key': 'grid-box-42', 'value': 42}, {'key': ...
# 2        [{'key': 'grid-box-42', 'value': 42}, {'key': ...
# 3        [{'key': 'grid-box-42', 'value': 42}, {'key': ...
# 4        [{'key': 'grid-box-42', 'value': 42}, {'key': ...
# 5        [{'key': 'grid-box-42', 'value': 42}, {'key': ...
# 6        [{'key': 'grid-box-42', 'value': 42}, {'key': ...
# 7        [{'key': 'grid-box-42', 'value': 42}, {'key': ...
# 8        [{'key': 'grid-box-42', 'value': 0}, {'key': '...
# 9        [{'key': 'grid-box-42', 'value': 0}, {'key': '...
# 10       [{'key': 'grid-box-42', 'value': 42}, {'key': ...
# 11       [{'key': 'grid-box-42', 'value': 42}, {'key': ...
# 12       [{'key': 'grid-box-42', 'value': 42}, {'key': ...
# 13       [{'key': 'grid-box-42', 'value': 42}, {'key': ...
# 14       [{'key': 'grid-box-42', 'value': 0}, {'key': '...
# 15       [{'key': 'grid-box-42', 'value': 42}, {'key': ...
# ...
